# %% [markdown]
# <a href="https://colab.research.google.com/github/PranavPanure/ML-sem2/blob/main/Assignment_1_ML_53.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Name: Pranav Bhushan Panure
#
# Roll no: 53
#
# Class: CSAI D
#
# Prn: 12411151
#
# kaggle dataset: https://www.kaggle.com/datasets/azminetoushikwasi/cr7-cristiano-ronaldo-all-club-goals-stats

# %%
import pandas as pd
import numpy as np

# %%
df_csv = pd.read_csv("GoatData.csv")
df_csv.head()
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10-07-02     H  Sporting CP
# 1  02/03             Liga Portugal             6  10-07-02     H  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02     A  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H  Sporting CP
#
#                   Opponent Result Playing_Position Minute At_score  \
# 0            Moreirense FC   3:00               LW     34     2:00
# 1            Moreirense FC   3:00               LW   90+5     3:00
# 2              Boavista FC   1:02              NaN     88     1:02
# 3             CD Estarreja   4:01              NaN     67     3:00
# 4  FC Oliveira do Hospital   8:01              NaN     13     3:00
#
#                 Type     Goal_assist
# 0           Solo run             NaN
# ...

# %%
df_csv.tail(4)
# Out:
#     Season       Competition Matchday     Date Venue         Club   Opponent  \
# 706  22/23  Saudi Pro League       18  2/25/23     A  Al-Nassr FC   Damac FC
# 707  22/23  Saudi Pro League       18  2/25/23     A  Al-Nassr FC   Damac FC
# 708  22/23  Saudi Pro League       18  2/25/23     A  Al-Nassr FC   Damac FC
# 709  22/23  Saudi Pro League       21  3/18/23     H  Al-Nassr FC  Abha Club
#
#     Result Playing_Position Minute At_score                 Type  \
# 706    0:3               CF     18      0:1              Penalty
# 707    0:3               CF     23      0:2     Left-footed shot
# 708    0:3               CF     44      0:3  Counter attack goal
# 709    2:1               CF     78      1:1     Direct free kick
#
#            Goal_assist
# 706                 \t
# 707  Sultan Al-Ghannam
# 708        Ayman Yahya
# 709                NaN

# %%
df_csv.index
# Out:
# RangeIndex(start=0, stop=710, step=1)

# %%
df_csv.columns
# Out:
# Index(['Season', 'Competition', 'Matchday', 'Date', 'Venue', 'Club',
#        'Opponent', 'Result', 'Playing_Position', 'Minute', 'At_score', 'Type',
#        'Goal_assist'],
#       dtype='object')

# %%
df_csv.to_numpy()
# Out:
# array([['02/03', 'Liga Portugal', '6', ..., '2:00', 'Solo run', nan],
#        ['02/03', 'Liga Portugal', '6', ..., '3:00', 'Header',
#         'Rui Jorge'],
#        ['02/03', 'Liga Portugal', '8', ..., '1:02', 'Right-footed shot',
#         'Carlos Martins'],
#        ...,
#        ['22/23', 'Saudi Pro League', '18', ..., '0:2',
#         'Left-footed shot', 'Sultan Al-Ghannam'],
#        ['22/23', 'Saudi Pro League', '18', ..., '0:3',
#         'Counter attack goal', 'Ayman Yahya'],
#        ['22/23', 'Saudi Pro League', '21', ..., '1:1',
#         'Direct free kick', nan]], dtype=object)

# %%
df_csv.T
# Out:
#                             0              1                  2    \
# Season                    02/03          02/03              02/03
# Competition       Liga Portugal  Liga Portugal      Liga Portugal
# Matchday                      6              6                  8
# Date                   10-07-02       10-07-02           10/26/02
# Venue                         H              H                  A
# Club                Sporting CP    Sporting CP        Sporting CP
# Opponent          Moreirense FC  Moreirense FC        Boavista FC
# Result                     3:00           3:00               1:02
# Playing_Position             LW             LW                NaN
# Minute                       34           90+5                 88
# At_score                   2:00           3:00               1:02
# Type                   Solo run         Header  Right-footed shot
# Goal_assist                 NaN      Rui Jorge     Carlos Martins
#
# ...

# %%
df_csv.sort_index(axis=1, ascending=False)
# Out:
#     Venue                 Type Season Result Playing_Position  \
# 0       H             Solo run  02/03   3:00               LW
# 1       H               Header  02/03   3:00               LW
# 2       A    Right-footed shot  02/03   1:02              NaN
# 3       H     Left-footed shot  02/03   4:01              NaN
# 4       H                  NaN  02/03   8:01              NaN
# ..    ...                  ...    ...    ...              ...
# 705     A    Right-footed shot  22/23    0:4               CF
# 706     A              Penalty  22/23    0:3               CF
# 707     A     Left-footed shot  22/23    0:3               CF
# 708     A  Counter attack goal  22/23    0:3               CF
# 709     H     Direct free kick  22/23    2:1               CF
#
#                     Opponent Minute      Matchday        Goal_assist  \
# 0              Moreirense FC     34             6                NaN
# 1              Moreirense FC   90+5             6          Rui Jorge
# ...

# %%
df_csv.shape
# Out:
# (710, 13)

# %% [markdown]
# null and their sum

# %%
df_csv.isnull().sum()
# Out:
# Season                0
# Competition           0
# Matchday              0
# Date                  0
# Venue                 0
# Club                  0
# Opponent              0
# Result                0
# Playing_Position     58
# Minute                0
# At_score              0
# Type                 15
# Goal_assist         246
# dtype: int64

# %% [markdown]
# info of data

# %%
df_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 710 entries, 0 to 709
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Season            710 non-null    object
#  1   Competition       710 non-null    object
#  2   Matchday          710 non-null    object
#  3   Date              710 non-null    object
#  4   Venue             710 non-null    object
#  5   Club              710 non-null    object
#  6   Opponent          710 non-null    object
#  7   Result            710 non-null    object
#  8   Playing_Position  652 non-null    object
#  9   Minute            710 non-null    object
#  10  At_score          710 non-null    object
#  11  Type              695 non-null    object
#  12  Goal_assist       464 non-null    object
# dtypes: object(13)
# memory usage: 72.2+ KB

# %% [markdown]
# only selected coloumn

# %%
df_csv[['Season', 'Matchday']]
# Out:
#     Season      Matchday
# 0    02/03             6
# 1    02/03             6
# 2    02/03             8
# 3    02/03  Fourth Round
# 4    02/03   Fifth Round
# ..     ...           ...
# 705  22/23            16
# 706  22/23            18
# 707  22/23            18
# 708  22/23            18
# 709  22/23            21
#
# [710 rows x 2 columns]

# %% [markdown]
# only selected rows

# %%
df_csv.iloc[3]
# Out:
# Season                                 02/03
# Competition         Taca de Portugal Placard
# Matchday                        Fourth Round
# Date                                11/24/02
# Venue                                      H
# Club                             Sporting CP
# Opponent                        CD Estarreja
# Result                                  4:01
# Playing_Position                         NaN
# Minute                                    67
# At_score                                3:00
# Type                        Left-footed shot
# Goal_assist                     Cesar Prates
# Name: 3, dtype: object

# %%
df_csv.iloc[3:5, 0:2]
# Out:
#   Season               Competition
# 3  02/03  Taca de Portugal Placard
# 4  02/03  Taca de Portugal Placard

# %%
df_csv.iloc[[1, 2, 4], [0, 2]]
# Out:
#   Season     Matchday
# 1  02/03            6
# 2  02/03            8
# 4  02/03  Fifth Round

# %%
df_csv.iloc[1:3, :]
# Out:
#   Season    Competition Matchday      Date Venue         Club       Opponent  \
# 1  02/03  Liga Portugal        6  10-07-02     H  Sporting CP  Moreirense FC
# 2  02/03  Liga Portugal        8  10/26/02     A  Sporting CP    Boavista FC
#
#   Result Playing_Position Minute At_score               Type     Goal_assist
# 1   3:00               LW   90+5     3:00             Header       Rui Jorge
# 2   1:02              NaN     88     1:02  Right-footed shot  Carlos Martins

# %%
df_csv.iloc[:, 1:3]
# Out:
#                   Competition      Matchday
# 0               Liga Portugal             6
# 1               Liga Portugal             6
# 2               Liga Portugal             8
# 3    Taca de Portugal Placard  Fourth Round
# 4    Taca de Portugal Placard   Fifth Round
# ..                        ...           ...
# 705          Saudi Pro League            16
# 706          Saudi Pro League            18
# 707          Saudi Pro League            18
# 708          Saudi Pro League            18
# 709          Saudi Pro League            21
#
# [710 rows x 2 columns]

# %%
df_csv.iloc[0:5]
# Out:
#   Season               Competition      Matchday      Date Venue         Club  \
# 0  02/03             Liga Portugal             6  10-07-02     H  Sporting CP
# 1  02/03             Liga Portugal             6  10-07-02     H  Sporting CP
# 2  02/03             Liga Portugal             8  10/26/02     A  Sporting CP
# 3  02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H  Sporting CP
# 4  02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H  Sporting CP
#
#                   Opponent Result Playing_Position Minute At_score  \
# 0            Moreirense FC   3:00               LW     34     2:00
# 1            Moreirense FC   3:00               LW   90+5     3:00
# 2              Boavista FC   1:02              NaN     88     1:02
# 3             CD Estarreja   4:01              NaN     67     3:00
# 4  FC Oliveira do Hospital   8:01              NaN     13     3:00
#
#                 Type     Goal_assist
# 0           Solo run             NaN
# ...

# %% [markdown]
# Sorting

# %%
df_csv.sort_values(by='Minute', ascending=False)
# Out:
#     Season            Competition        Matchday      Date Venue  \
# 501  16/17    FIFA Club World Cup           Final  12/18/16     H
# 569  17/18  UEFA Champions League  Quarter-Finals  04-11-18     H
# 606  19/20                Serie A              10  10/30/19     H
# 332  13/14                 LaLiga               6   9/25/13     A
# 678  21/22  UEFA Champions League     Group Stage   9/29/21     H
# ..     ...                    ...             ...       ...   ...
# 183  10/11                 LaLiga              18  01-09-11     H
# 35   06/07         Premier League              11  11-04-06     H
# 354  13/14                 LaLiga              20   1/18/14     A
# 231  11/12                 LaLiga              17  12/17/11     A
# 127  09/10                 LaLiga               3   9/20/09     H
#
#                   Club             Opponent   Result Playing_Position Minute  \
# 501        Real Madrid      Kashima Antlers  4:2 AET               LW     97
# ...

# %%
df_csv[df_csv["Minute"] > "45"]
# Out:
#     Season               Competition      Matchday      Date Venue  \
# 1    02/03             Liga Portugal             6  10-07-02     H
# 2    02/03             Liga Portugal             8  10/26/02     A
# 3    02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 5    03/04            Premier League            11  11-01-03     H
# 6    03/04                    FA Cup   Fifth Round   2/14/04     H
# ..     ...                       ...           ...       ...   ...
# 700  22/23             Europa League   Group Stage  10/27/22     H
# 701  22/23          Saudi Pro League            15    2/3/23     A
# 704  22/23          Saudi Pro League            16    2/9/23     A
# 705  22/23          Saudi Pro League            16    2/9/23     A
# 709  22/23          Saudi Pro League            21   3/18/23     H
#
#                   Club         Opponent Result Playing_Position Minute  \
# 1          Sporting CP    Moreirense FC   3:00               LW   90+5
# ...

# %%
df = df_csv.copy()

# %%
df_csv.describe()
# Out:
#        Season Competition     Matchday      Date Venue         Club  \
# count     710         710          710       710   710          710
# unique     21          17           52       468     2            5
# top     14/15      LaLiga  Group Stage  09-12-15     H  Real Madrid
# freq       61         311           75         5   404          450
#
#           Opponent Result Playing_Position Minute At_score               Type  \
# count          710    710              652    710      710                695
# unique         129     57                5    106       43                 11
# top     Sevilla FC   3:00               LW     90     1:00  Right-footed shot
# freq            27     49              356     17      111                253
#
#           Goal_assist
# count             464
# unique             91
# top     Karim Benzema
# freq               44

# %% [markdown]
# Unique elements

# %%
df_csv['Minute'].unique()
# Out:
# array(['34', '90+5', '88', '67', '13', '80', '74', '89', '60', '4', '44',
#        '87', '9', '8', '54', '58', '45+1', '21', '76', '63', '90', '12',
#        '68', '14', '38', '45', '59', '23', '19', '73', '82', '10', '39',
#        '84', '85', '47', '50', '77', '49', '28', '5', '62', '51', '41',
#        '35', '90+3', '22', '81', '48', '70', '90+2', '69', '56', '79',
#        '16', '53', '3', '24', '32', '26', '25', '30', '43', '65', '11',
#        '6', '57', '61', '17', '27', '1', '75', '2', '64', '71', '18',
#        '78', '29', '36', '15', '55', '86', '90+1', '72', '20', '42',
#        '103', '46', '52', '90+4', '37', '66', '90+6', '31', '40', '120',
#        '83', '7', '33', '97', '104', '105', '109', '90+7', '45+7', '45+2'],
#       dtype=object)

# %% [markdown]
# count of unique elements

# %%
df_csv['Minute'].value_counts()
# Out:
# Minute
# 90      17
# 89      15
# 45      15
# 23      15
# 76      14
#         ..
# 105      1
# 109      1
# 90+7     1
# 45+7     1
# 45+2     1
# Name: count, Length: 106, dtype: int64

# %% [markdown]
# data types

# %%
df_csv.dtypes
# Out:
# Season              object
# Competition         object
# Matchday            object
# Date                object
# Venue               object
# Club                object
# Opponent            object
# Result              object
# Playing_Position    object
# Minute              object
# At_score            object
# Type                object
# Goal_assist         object
# dtype: object

# %%
df_csv.Type
# Out:
# 0                 Solo run
# 1                   Header
# 2        Right-footed shot
# 3         Left-footed shot
# 4                      NaN
#               ...
# 705      Right-footed shot
# 706                Penalty
# 707       Left-footed shot
# 708    Counter attack goal
# 709       Direct free kick
# Name: Type, Length: 710, dtype: object

# %%
df.fillna(value=0)
# Out:
#     Season               Competition      Matchday      Date Venue  \
# 0    02/03             Liga Portugal             6  10-07-02     H
# 1    02/03             Liga Portugal             6  10-07-02     H
# 2    02/03             Liga Portugal             8  10/26/02     A
# 3    02/03  Taca de Portugal Placard  Fourth Round  11/24/02     H
# 4    02/03  Taca de Portugal Placard   Fifth Round  12/18/02     H
# ..     ...                       ...           ...       ...   ...
# 705  22/23          Saudi Pro League            16    2/9/23     A
# 706  22/23          Saudi Pro League            18   2/25/23     A
# 707  22/23          Saudi Pro League            18   2/25/23     A
# 708  22/23          Saudi Pro League            18   2/25/23     A
# 709  22/23          Saudi Pro League            21   3/18/23     H
#
#             Club                 Opponent Result Playing_Position Minute  \
# 0    Sporting CP            Moreirense FC   3:00               LW     34
# ...

# %% [markdown]
# changing datatypes

# %%
df_csv['Type'] = df_csv['Type'].astype(str)
